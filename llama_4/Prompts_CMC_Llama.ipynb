# %% [markdown]
# # Prompts for the CMC: LLAMA 4 - Maverick 17B

# %% [markdown]
# Documentation for this notebook using Llama is listed as follows:
# - Llama API reference: https://llama.developer.meta.com/docs/api/chat/?team_id=762522652904006
# - Llama Cookbook: https://github.com/meta-llama/llama-cookbook/tree/main
# - Llama 4: https://www.llama.com/docs/model-cards-and-prompt-formats/llama4/
#
# Prompt templates have been modified from previous research by Alexis Cooper: https://github.com/AACooper1/GPTGeneralizationsData

# %%
pip install llama-api-client
# Out:
# ...
#   Obtaining dependency information for llama-api-client from https://files.pythonhosted.org/packages/99/08/5d7e6e7e6af5353391376288c200acacebb8e6b156d3636eae598a451673/llama_api_client-0.1.2-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.3 MB/s eta 0:00:00a 0:00:01
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-dotenv
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import dotenv
from llama_api_client import LlamaAPIClient
from dotenv import load_dotenv

# %%
# Use the path to add your .env file with the Llama API key
print(os.getcwd())

# %%
dotenv.load_dotenv('your_path/.env')

client = LlamaAPIClient()

# %%
# Functions are different from other models like GPT
help(client.chat.completions.create)
# Out:
# Help on method create in module llama_api_client.resources.chat.completions:
#
# ...

# %% [markdown]
# ## Importing all example sentences

# %%
# Too many examples to unpack in just one file, so we divided all sentences into 4 different .txt docs.
print(examples)
type(examples)
print(len(examples))
# Out:
# 1. She ejected him into the street.
# 2. He steered her through the tunnel.
# 3. She launched it towards the enemy.
# 4. He moved her out of the room.
# 5. He ejected it under the porch.
# 6. She steered it over the wall.
# 7. She launched it across the room.
# 8. She kicked it through the street.
# 9. She squeezed it into the suitcase.
# 10. He pushed it towards the enemy.
# 11. She hit it out of the room.
# 12. She kicked him under the table.
# 13. He squeezed it in the suitcase.
# 14. He pushed it over the wall.
# 15. He hit it across the room.
# 16. He stuffed it into the bag.
# 17. She fed it into the funnel.
# 18. She washed it off the sidewalk.
# 19. He hosed it out of the street.
# 20. He stuffed it under the staircase.
# 21. He fed it in the funnel.
# 22. He washed it from the sidewalk.
# 23. She hosed it across the street.
# 24. He snored her into the guest room.
# 25. She sneezed it off the table.
# 26. She laughed him out of the field.
# ...

# %%
with open('cmc_examples_1.txt', "r") as sents:
    sents_1 = sents.read()

# %%
print(sents_1)
# Out:
# 1. She ejected him into the street.
# 2. He steered her through the tunnel.
# 3. She launched it towards the enemy.
# 4. He moved her out of the room.
# 5. He ejected it under the porch.
# 6. She steered it over the wall.
# 7. She launched it across the room.
# 8. She kicked it through the street.

# %%
with open('cmc_examples_2.txt', "r") as sents:
    sents_2 = sents.read()
    
print(sents_2)
# Out:
# 9. She squeezed it into the suitcase.
# 10. He pushed it towards the enemy.
# 11. She hit it out of the room.
# 12. She kicked him under the table.
# 13. He squeezed it in the suitcase.
# 14. He pushed it over the wall.
# 15. He hit it across the room.
# 16. He stuffed it into the bag.

# %%
with open('cmc_examples_3.txt', "r") as sents:
    sents_3 = sents.read()
    
print(sents_3)
# Out:
# 17. She fed it into the funnel.
# 18. She washed it off the sidewalk.
# 19. He hosed it out of the street.
# 20. He stuffed it under the staircase.
# 21. He fed it in the funnel.
# 22. He washed it from the sidewalk.
# 23. She hosed it across the street.
# 24. He snored her into the guest room.

# %%
with open('cmc_examples_4.txt', "r") as sents:
    sents_4 = sents.read()
    
print(sents_4)
# Out:
# 25. She sneezed it off the table.
# 26. She laughed him out of the field.
# 27. She jeered him out of the business.
# 28. She glared him onto the stage.
# 29. He snored her under the table.
# 30. She sneezed it across the table.
# 31. She laughed him over the bridge.
# 32. He jeered it around the cage.
# 33. She glared him against the wall.

# %%
completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": f"""
            You will receive 8 prompt sentences that are:{sents_1}. 
            The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly.
            Each question will have three answers, which will start with:
            'ASSISTANT(1):' for the first answer.
            'ASSISTANT(2):' for the second answer.
            'ASSISTANT(3):' for the first answer.
            
            REMEMBER: You MUST answer every question for the 8 sentences. Do not leave any question unanswered. Follow the specified format for all sentences, questions and answers.
            """,
        },
        {
            "role": "user",
            "content": f"""Taking into account the 8 sentences provided, answer the following questions: 
            1. Did he/she/it move?
            2. Where was he/she/it at the beginning of the event described in the sentence above?
            3. Where was he/she/it at the end of the event described in the sentence above?
            4. Why did he/she/it move?
            5. Who or what performed the action?
            6. Please describe this event in another way.
            
            You MUST answer all questions for the 8 sentences. Do not leave any question unanswered.""",
        },
    ],
    #repetition_penalty=2,
    #max_completion_tokens=100,
    temperature=0,
    max_completion_tokens=6000,
)

print(completion.completion_message.content.text)
# Out:
# I'll be happy to help. Here are the answers to the questions for each of the 8 sentences.
#
# **Sentence 1: She ejected him into the street.**
# 1. Did he/she/it move?
#     ASSISTANT(1): Yes, he moved.
#     ASSISTANT(2): Yes, the person referred to as 'him' moved.
#     ASSISTANT(3): The subject 'him' was moved.
# 2. Where was he/she/it at the beginning of the event described in the sentence above?
#     ASSISTANT(1): Inside, presumably a building or a room.
#     ASSISTANT(2): Not in the street.
#     ASSISTANT(3): With her, or in her presence.
# 3. Where was he/she/it at the end of the event described in the sentence above?
#     ASSISTANT(1): In the street.
#     ASSISTANT(2): Outside.
#     ASSISTANT(3): Into the street.
# 4. Why did he/she/it move?
#     ASSISTANT(1): Because she ejected him.
#     ASSISTANT(2): The reason is not specified, but it was due to her action.
#     ASSISTANT(3): She forced him out.
# 5. Who or what performed the action?
#     ASSISTANT(1): She.
# ...

# %%
completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": f"""
            You will receive 8 prompt sentences that are:{sents_2}. 
            The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly.
            Each question will have three answers, which will start with:
            'ASSISTANT(1):' for the first answer.
            'ASSISTANT(2):' for the second answer.
            'ASSISTANT(3):' for the first answer.
            
            REMEMBER: You MUST answer every question for the 8 sentences. Do not leave any question unanswered. Follow the specified format for all sentences, questions and answers.
            """,
        },
        {
            "role": "user",
            "content": f"""Taking into account the 8 sentences provided, answer the following questions: 
            1. Did he/she/it move?
            2. Where was he/she/it at the beginning of the event described in the sentence above?
            3. Where was he/she/it at the end of the event described in the sentence above?
            4. Why did he/she/it move?
            5. Who or what performed the action?
            6. Please describe this event in another way.
            
            You MUST answer all questions for the 8 sentences. Do not leave any question unanswered.""",
        },
    ],
    #repetition_penalty=2,
    #max_completion_tokens=100,
    temperature=0,
    max_completion_tokens=6000,
)

print(completion.completion_message.content.text)
# Out:
# I'll be happy to help. Here are the answers to the questions for each of the 8 sentences.
#
# **9. She squeezed it into the suitcase.**
# 1. Did he/she/it move?
#     ASSISTANT(1): Yes, it moved.
#     ASSISTANT(2): Yes, she moved it.
#     ASSISTANT(3): The object was moved.
# 2. Where was he/she/it at the beginning of the event described in the sentence above?
#     ASSISTANT(1): Outside the suitcase.
#     ASSISTANT(2): Not in the suitcase.
#     ASSISTANT(3): Not inside the suitcase.
# 3. Where was he/she/it at the end of the event described in the sentence above?
#     ASSISTANT(1): Inside the suitcase.
#     ASSISTANT(2): In the suitcase.
#     ASSISTANT(3): Inside the suitcase.
# 4. Why did he/she/it move?
#     ASSISTANT(1): Because she squeezed it.
#     ASSISTANT(2): To fit into the suitcase.
#     ASSISTANT(3): She wanted to put it in the suitcase.
# 5. Who or what performed the action?
#     ASSISTANT(1): She.
#     ASSISTANT(2): The subject, she.
# ...

# %%
completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": f"""
            You will receive 8 prompt sentences that are:{sents_3}. 
            The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly.
            Each question will have three answers, which will start with:
            'ASSISTANT(1):' for the first answer.
            'ASSISTANT(2):' for the second answer.
            'ASSISTANT(3):' for the first answer.
            
            REMEMBER: You MUST answer every question for the 8 sentences. Do not leave any question unanswered. Follow the specified format for all sentences, questions and answers.
            """,
        },
        {
            "role": "user",
            "content": f"""Taking into account the 8 sentences provided, answer the following questions: 
            1. Did he/she/it move?
            2. Where was he/she/it at the beginning of the event described in the sentence above?
            3. Where was he/she/it at the end of the event described in the sentence above?
            4. Why did he/she/it move?
            5. Who or what performed the action?
            6. Please describe this event in another way.
            
            You MUST answer all questions for the 8 sentences. Do not leave any question unanswered.""",
        },
    ],
    #repetition_penalty=2,
    #max_completion_tokens=100,
    temperature=0,
    max_completion_tokens=6000,
)

print(completion.completion_message.content.text)
# Out:
# I'll be happy to help. Here are the answers to the questions for each of the 8 sentences.
#
# **Sentence 17: She fed it into the funnel.**
#
# 1. ASSISTANT(1): Yes, it moved.
# ASSISTANT(2): The sentence doesn't explicitly state that "she" or "it" moved, but "it" was fed into the funnel, so "it" moved.
# ASSISTANT(3): "It" moved from one location to another.
#
# 2. ASSISTANT(1): The sentence doesn't specify the initial location of "it".
# ASSISTANT(2): "It" was outside or not in the funnel.
# ASSISTANT(3): The location of "it" before being fed into the funnel is not specified.
#
# 3. ASSISTANT(1): "It" was in the funnel.
# ASSISTANT(2): At the end, "it" was inside the funnel.
# ASSISTANT(3): The final location of "it" was inside the funnel.
#
# 4. ASSISTANT(1): The reason "it" moved is that "she" fed it into the funnel.
# ASSISTANT(2): "It" moved because "she" performed an action on it.
# ASSISTANT(3): The movement of "it" was caused by "she" feeding it into the funnel.
#
# ...

# %%
completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": f"""
            You will receive 8 prompt sentences that are:{sents_4}. 
            The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly.
            Each question will have three answers, which will start with:
            'ASSISTANT(1):' for the first answer.
            'ASSISTANT(2):' for the second answer.
            'ASSISTANT(3):' for the first answer.
            
            REMEMBER: You MUST answer every question for the 8 sentences. Do not leave any question unanswered. Follow the specified format for all sentences, questions and answers.
            """,
        },
        {
            "role": "user",
            "content": f"""Taking into account the 8 sentences provided, answer the following questions: 
            1. Did he/she/it move?
            2. Where was he/she/it at the beginning of the event described in the sentence above?
            3. Where was he/she/it at the end of the event described in the sentence above?
            4. Why did he/she/it move?
            5. Who or what performed the action?
            6. Please describe this event in another way.
            
            You MUST answer all questions for the 8 sentences. Do not leave any question unanswered.""",
        },
    ],
    #repetition_penalty=2,
    #max_completion_tokens=100,
    temperature=0,
    max_completion_tokens=6000,
)

print(completion.completion_message.content.text)
# Out:
# I'll be happy to help. Here are the answers to the questions for each of the 8 sentences.
#
# **Sentence 25: She sneezed it off the table.**
#
# 1. ASSISTANT(1): Yes, it moved.
# ASSISTANT(2): Yes, the object moved.
# ASSISTANT(3): The object was displaced.
#
# 2. ASSISTANT(1): On the table.
# ASSISTANT(2): The object was initially on the table.
# ASSISTANT(3): It was on the table.
#
# 3. ASSISTANT(1): Off the table.
# ASSISTANT(2): The object ended up off or away from the table.
# ASSISTANT(3): It was no longer on the table.
#
# 4. ASSISTANT(1): Because she sneezed.
# ASSISTANT(2): The movement was caused by her sneeze.
# ASSISTANT(3): Her sneeze made it move.
#
# 5. ASSISTANT(1): She did.
# ASSISTANT(2): The action was performed by her sneeze.
# ASSISTANT(3): She performed the action through her sneeze.
#
# 6. ASSISTANT(1): She accidentally knocked it off the table while sneezing.
# ASSISTANT(2): Her sneeze caused the object to fall off the table.
# ...

# %% [markdown]
# # TEST PERFORMED UNTIL ACHIEVING THE OPTIMAL SOLUTION

# %% [markdown]
# ## Prompting each sentence

# %%
sents_list = [
    "She ejected him into the street.",
    "He steered her through the tunnel.",
    "She launched it towards the enemy.",
    "He moved her out of the room.",
    "He ejected it under the porch.",
    "She steered it over the wall.",
    "She launched it across the room.",    
    "She kicked it through the street.",
    "She squeezed it into the suitcase.",
    "He pushed it towards the enemy.",
    "She hit it out of the room.",
    "She kicked him under the table.",
    "He squeezed it in the suitcase.",
    "He pushed it over the wall.",
    "He hit it across the room.",
    "He stuffed it into the bag.",
    "She fed it into the funnel.",
    "She washed it off the sidewalk.",
    "He hosed it out of the street.",
    "He stuffed it under the staircase.",
    "He fed it in the funnel.",
    "He washed it from the sidewalk.",
    "She hosed it across the street.",
    "He snored her into the guest room.",
    "She sneezed it off the table",
    "She laughed him out of the field.",
    "She jeered him out of the business.",
    "She glared him onto the stage.",
    "He snored her under the table.",
    "She sneezed it across the table.",
    "She laughed him over the bridge.",
    "He jeered it around the cage.",
    "She glared him against the wall."
]

# %%
for i, sent in enumerate(sents_list, start=1):
    completion = client.chat.completions.create(
        model="Llama-4-Maverick-17B-128E-Instruct-FP8",
        messages=[
            {
                "role": "system",
                "content": f"""
                You will receive one prompt sentence: "{sent}".
                The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly.
                Each question will have three answers, which will start with:
                'ASSISTANT(1):' for the first answer.
                'ASSISTANT(2):' for the second answer.
                'ASSISTANT(3):' for the third answer.
                REMEMBER: You MUST answer every question for the sentence. Do not leave any question unanswered. Follow the specified format.
                """,
            },
            {
                "role": "user",
                "content": """Taking into account the sentence provided, answer the following questions:
                1. Did he/she/it move?
                2. Where was he/she/it at the beginning of the event described in the sentence above?
                3. Where was he/she/it at the end of the event described in the sentence above?
                4. Why did he/she/it move?
                5. Who or what performed the action?
                6. Please describe this event in another way.
                
                You MUST answer all questions for the given sentence. Do not leave any question unanswered.
                """,
            },
        ],
        temperature=0,
        #max_completion_tokens=10000,
    )

    print(f"\n{i}. {sent}")
    print(completion.completion_message.content.text)
# Out:
# 1. She ejected him into the street.
# 1. Did he/she/it move?
# ASSISTANT(1): Yes, 'he' moved.
# ASSISTANT(2): The sentence implies movement of 'him'.
# ASSISTANT(3): 'He' was ejected, so yes, he moved.
#
# 2. Where was he/she/it at the beginning of the event described in the sentence above?
# ASSISTANT(1): 'He' was inside, presumably in a building or a vehicle.
# ASSISTANT(2): The starting location is not explicitly stated but is implied to be inside or with 'her'.
# ASSISTANT(3): 'He' was with 'her', likely inside a place.
#
# 3. Where was he/she/it at the end of the event described in the sentence above?
# ASSISTANT(1): 'He' was in the street.
# ASSISTANT(2): The final location of 'him' is the street.
# ASSISTANT(3): 'He' ended up in the street.
#
# 4. Why did he/she/it move?
# ASSISTANT(1): 'He' moved because 'she' ejected him.
# ASSISTANT(2): The reason for the ejection is not specified, but it implies a forceful or decisive action by 'her'.
# ...

# %% [markdown]
# ## Test 1: Same prompt as GPT4 (Using the assistant role)

# %%
completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": "She ejected him into the street."
        },
        {
            "role": "user",
            "content": "1. Did he move? 2. Where was he at the beginning of the event described in the sentence above? 3. Where was he at the end of the event described in the sentence above? 4. Why did he move? 5. Who or what performed the action? 6. Please describe this event in another way.",
            
        },
        {
            "role": "assistant",
            "content": "You will receive a prompt sentence from the system. The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly. Each question will have three answers, which will start with: 'ASSISTANT(1):' for the first answer. 'ASSISTANT(2):' for the second answer. 'ASSISTANT(3):' for the first answer. There will be a newline in between of each answer.",
        }
    ],
    # Repetition penalty here controls the likelihood of generating original responses
    # Answers are not what expected when using it so we will comment this line after a few tests
    repetition_penalty=2,
    temperature=0,
    #max_completion_tokens=100,
)

# %%
print(completion.completion_message.content.text)
# Out:
# 1. Did he move?
#
# ASSISTANT(3): Yes, the sentence implies that "he" was moved or thrown into a different location.
#
# 2 was not answered in this response; continuing with other questions.
#
# 3 is answered below as 3.
#
#
# 3 was rephrased to:  Where was 'He' at 'the end of event'?
#
#
# 3.Where Was He At The End Of Event?
#
#  ASSistant wasn't numbered properly so I will just give all responses now for each.
#
#
# For question one - Did "He Move"?
#  ASSistant (One) :Yes
#  ASSist (TWO) - It can be inferred from context as yes since being ejected results in movement typically unless obstructed or other external factors are at play
#  Assist three as given before-
#
#
#
# For Question Two-Where Was HE At Beginning?
#  Asst One-Inside some place/ building etc as eject typically means out and thus inside prior
#
# Asstwo-some enclosed space like house building room
#
# AstThree implicitly inside as per action described.
#
#
#
# ...

# %% [markdown]
# ## Test 2: Prompt does not specify the number of assistants

# %%
completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": "She ejected him into the street."
        },
        {
            "role": "user",
            "content": "1. Did he move? 2. Where was he at the beginning of the event described in the sentence above? 3. Where was he at the end of the event described in the sentence above? 4. Why did he move? 5. Who or what performed the action? 6. Please describe this event in another way.",
            
        },
        {
            "role": "assistant",
            "content": "You will receive a prompt sentence from the system. The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly.",
        }
    ],
    repetition_penalty=2,
    temperature=0,
    #max_completion_tokens=100,
)

# %%
print(completion.completion_message.content.text)
# Out:
# 1. Yes, he moved.
# 2.He was inside (presumably a building or vehicle) at the beginning of this event
# 3.At  He  At
# 4..He likely didn't move under his own power; rather it is more probable that 'she' caused him to be relocated from one location(inside)she ejectedto another(outside in thestreet).
# 5.'She'did.the action described as'ejecting'.
# 6An alternative way o describe:thevent could b "shemphysically threwor forcedhim out ontothe street"

# %% [markdown]
# ## Tests 3 & 4: Repetition penalty is commented

# %%
completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": "She ejected him into the street."
        },
        {
            "role": "user",
            "content": "1. Did he move? 2. Where was he at the beginning of the event described in the sentence above? 3. Where was he at the end of the event described in the sentence above? 4. Why did he move? 5. Who or what performed the action? 6. Please describe this event in another way.",
            
        },
        {
            "role": "assistant",
            "content": "You will receive a prompt sentence from the system. The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly.",
        }
    ],
    #repetition_penalty=2,
    temperature=0,
    #max_completion_tokens=100,
)

# %%
print(completion.completion_message.content.text)
# Out:
# 1. Yes, he moved.
# 2. He was inside (presumably a building or a vehicle) at the beginning of the event.
# 3. He was in the street at the end of the event.
# 4. He moved because she ejected him.
# 5. She performed the action.
# 6. She threw him out into the street.

# %%
dotenv.load_dotenv('/Users/federicoortegariba/Desktop/Escritorio/Universidad/CUBoulder/Research/.env')

client = LlamaAPIClient()

completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": "She ejected him into the street."
        },
        {
            "role": "user",
            "content": "1. Did he move? 2. Where was he at the beginning of the event described in the sentence above? 3. Where was he at the end of the event described in the sentence above? 4. Why did he move? 5. Who or what performed the action? 6. Please describe this event in another way.",
            
        },
        {
            "role": "assistant",
            "content": "You will receive a prompt sentence from the system. The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly. Each question will have three answers, which will start with: 'ASSISTANT(1):' for the first answer. 'ASSISTANT(2):' for the second answer. 'ASSISTANT(3):' for the first answer. There will be a newline in between of each answer.",
        }
    ],
    #repetition_penalty=2,
    temperature=0,
    #max_completion_tokens=100,
)

# %%
print(completion.completion_message.content.text)
# Out:
# 1. Did he move?
#
# ASSISTANT(1): Yes, he moved from one location to another.
#
# ASSISTANT(2): The sentence implies that he was ejected, so yes, he was moved or thrown.
#
# ASSISTANT(3): The action of ejecting him into the street indicates that he did indeed move.
#
#
# 2. Where was he at the beginning of the event described in the sentence above?
#
# ASSISTANT(1): He was inside, presumably in a building or a vehicle, before being ejected.
#
# ASSISTANT(2): The sentence doesn't specify the exact starting location, but it implies he was not in the street initially.
#
# ASSISTANT(3): At the beginning, he was not in the street; otherwise, the action described wouldn't make sense.
#
#
# 3. Where was he at the end of the event described in the sentence above?
#
# ASSISTANT(1): He was in the street at the end of the event.
#
# ASSISTANT(2): The event concluded with him being in the street.
#
# ASSISTANT(3): The outcome of the action was that he ended up in the street.
#
#
# ...

# %% [markdown]
# ## Test 5: Inference with more example sentences in the system role

# %%
client = LlamaAPIClient()

completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": "1. She ejected him into the street. 2. He steered her through the tunnel. 3. She launched it towards the enemy.",
        },
        {
            "role": "user",
            "content": "1. Did he move? 2. Where was he at the beginning of the event described in the sentence above? 3. Where was he at the end of the event described in the sentence above? 4. Why did he move? 5. Who or what performed the action? 6. Please describe this event in another way.",
            
        },
        {
            "role": "assistant",
            "content": "You will receive 3 prompt sentences from the system. The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly. Each question will have three answers, which will start with: The sentence provided. {\n} 'ASSISTANT(1):' for the first answer. {\n} 'ASSISTANT(2):' for the second answer. {\n} 'ASSISTANT(3):' for the first answer.",
        }
    ],
    #repetition_penalty=2,
    temperature=0,
    #max_completion_tokens=100,
)

# %%
print(completion.completion_message.content.text)
# Out:
# Let's analyze the given sentences one by one.
#
# ### Sentence 1: She ejected him into the street.
#
# 1. Did he move?
# - ASSISTANT(1): Yes, he moved from one location to another.
# - ASSISTANT(2): The sentence implies that "he" was relocated or moved.
# - ASSISTANT(3): The action of ejecting caused him to change his location.
#
# 2. Where was he at the beginning of the event described in the sentence above?
# - ASSISTANT(1): The sentence doesn't explicitly state his initial location, but it implies he was not in the street.
# - ASSISTANT(2): He was presumably inside or not in the street.
# - ASSISTANT(3): His initial location is not specified, but it was not the street.
#
# 3. Where was he at the end of the event described in the sentence above?
# - ASSISTANT(1): He was in the street.
# - ASSISTANT(2): The outcome of the action was that he ended up in the street.
# - ASSISTANT(3): At the end of the event, he was in the street.
#
# 4. Why did he move?
# ...

# %% [markdown]
# ## Tests 6 & 7: Inference with all examples at once

# %%
completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": f"You will receive 33 prompt sentences that are:{examples}. The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly. Each question will have three answers, which will start with: The sentence provided.\n 'ASSISTANT(1):' for the first answer.\n 'ASSISTANT(2):' for the second answer.\n 'ASSISTANT(3):' for the first answer. Provide answers for the 33 prompt sentences.",
        },
        {
            "role": "user",
            "content": "1. Did he/she move? 2. Where was he/she at the beginning of the event described in the sentence above? 3. Where was he/she at the end of the event described in the sentence above? 4. Why did he/she move? 5. Who or what performed the action? 6. Please describe this event in another way.",
            
        },
    ],
    #repetition_penalty=2,
    temperature=0,
    #max_completion_tokens=100,
)

# %%
print(completion.completion_message.content.text)
# Out:
# I'll be happy to help. I'll respond to the 6 questions for each of the 33 sentences.
#
#
# ### Sentence 1: She ejected him into the street.
#
# 1. Did he/she move?
#  'ASSISTANT(1):' Yes, he moved.
#  'ASSISTANT(2):' Yes, she moved him.
#  'ASSISTANT(3):' Yes, both he and she moved.
#
# 2. Where was he/she at the beginning of the event described in the sentence above?
#  'ASSISTANT(1):' The sentence doesn't specify where she was, but he was presumably inside or with her.
#  'ASSISTANT(2):' He was with her or inside.
#  'ASSISTANT(3):' The exact location isn't specified.
#
# 3. Where was he/she at the end of the event described in the sentence above?
#  'ASSISTANT(1):' He was in the street.
#  'ASSISTANT(2):' She was presumably still where she started, having ejected him.
#  'ASSISTANT(3):' He was in the street, and she was elsewhere.
#
# 4. Why did he/she move?
#  'ASSISTANT(1):' The sentence doesn't specify why she ejected him.
# ...

# %%
# The issue here ends up being the fact that the system needs to be prompted to do exactly
# the number of sentences that we want or it will just provide a summary instead of 
# the output that is expected

completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": f"You will receive 33 prompt sentences that are:{examples}. The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly. Each question will have three answers, which will start with: The sentence provided.\n 'ASSISTANT(1):' for the first answer.\n 'ASSISTANT(2):' for the second answer.\n 'ASSISTANT(3):' for the first answer. Provide answers for the 33 prompt sentences.",
        },
        {
            "role": "user",
            "content": "1. Did he/she/it move? 2. Where was he/she/it at the beginning of the event described in the sentence above? 3. Where was he/she/it at the end of the event described in the sentence above? 4. Why did he/she/it move? 5. Who or what performed the action? 6. Please describe this event in another way.",
            
        },
    ],
    #repetition_penalty=2,
    temperature=0,
    #max_completion_tokens=100,
)

# %%
print(completion.completion_message.content.text)
# Out:
# I'll be happy to help. Here are the answers to your questions for each of the 33 prompt sentences.
#
# ### Sentence 1: She ejected him into the street.
# 1. Did he/she/it move?
#  'ASSISTANT(1):' Yes, he moved.
#  'ASSISTANT(2):' Yes, the person referred to as "him" moved.
#  'ASSISTANT(3):' Yes, "him" was ejected.
#
# 2. Where was he/she/it at the beginning of the event described in the sentence above?
#  'ASSISTANT(1):' The sentence provided doesn't specify the initial location of "him" before being ejected.
#  'ASSISTANT(2):' The initial location is not directly stated but implies "him" was not in the street.
#  'ASSISTANT(3):' The sentence implies "him" was inside or not in the street.
#
# 3. Where was he/she/it at the end of the event described in the sentence above?
#  'ASSISTANT(1):' He was in the street.
#  'ASSISTANT(2):' "Him" ended up in the street.
#  'ASSISTANT(3):' The final location of "him" was in the street.
#
# 4. Why did he/she/it move?
# ...

# %% [markdown]
# ## Test 8: Specifying it MUST complete it

# %%
completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": f"You will receive 33 prompt sentences that are:{examples}. The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly. Each question will have three answers, which will start with: The sentence provided.\n 'ASSISTANT(1):' for the first answer.\n 'ASSISTANT(2):' for the second answer.\n 'ASSISTANT(3):' for the first answer. You must answer all 33 sentences. Do not leave a sentence unanswered.",
        },
        {
            "role": "user",
            "content": "1. Did he/she/it move? 2. Where was he/she/it at the beginning of the event described in the sentence above? 3. Where was he/she/it at the end of the event described in the sentence above? 4. Why did he/she/it move? 5. Who or what performed the action? 6. Please describe this event in another way.",
        },
    ],
    #repetition_penalty=2,
    temperature=0,
    #max_completion_tokens=100,
)

# %%
print(completion.completion_message.content.text)
# Out:
# I'll be happy to help answer the questions for each of the 33 sentences. Here are the answers:
#
# **1. She ejected him into the street.**
# 1. Did he/she/it move?
#  'ASSISTANT(1):' Yes, he moved.
#  'ASSISTANT(2):' The sentence implies that 'he' was moved by 'she'.
#  'ASSISTANT(3):' Yes, the subject 'him' was ejected, so he moved.
# 2. Where was he/she/it at the beginning of the event described in the sentence above?
#  'ASSISTANT(1):' The sentence doesn't specify the exact starting location, but it implies he was not in the street initially.
#  'ASSISTANT(2):' He was presumably inside or somewhere other than the street.
#  'ASSISTANT(3):' The starting location is not specified, but it was not the street.
# 3. Where was he/she/it at the end of the event described in the sentence above?
#  'ASSISTANT(1):' He was in the street.
#  'ASSISTANT(2):' The final location of 'him' was in the street.
#  'ASSISTANT(3):' At the end, he was in the street.
# 4. Why did he/she/it move?
# ...

# %% [markdown]
# ## Test 9: Structures ouput - JSON

# %%
completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": f"You will receive 33 prompt sentences that are:{examples}. The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly. Each question will have three answers, which will start with: The sentence provided.\n 'ASSISTANT(1):' for the first answer.\n 'ASSISTANT(2):' for the second answer.\n 'ASSISTANT(3):' for the first answer. You must answer all 33 sentences. Do not leave a sentence unanswered. Put all the sentences, questions and answers into the specified JSON format",
        },
        {
            "role": "user",
            "content": f"Taking into account these 33 sentences: {examples}, answer the following questions: 1. Did he/she/it move? 2. Where was he/she/it at the beginning of the event described in the sentence above? 3. Where was he/she/it at the end of the event described in the sentence above? 4. Why did he/she/it move? 5. Who or what performed the action? 6. Please describe this event in another way.",
        },
    ],
    #repetition_penalty=2,
    #max_completion_tokens=100,
    temperature=0,
    response_format={
        "type": "json_schema",
        "json_schema": {
            "name": "PromptResponse",
            "schema": {
                "type": "object",
                "properties": {
                    "results": {
                        "type": "array",
                        "items": {
                            "type": "object",
                            "properties": {
                                "sentence": { "type": "string" },
                                "answers": {
                                    "type": "object",
                                    "properties": {
                                        "1": {
                                            "type": "object",
                                            "properties": {
                                                "ASSISTANT 1": { "type": "string" },
                                                "ASSISTANT 2": { "type": "string" },
                                                "ASSISTANT 3": { "type": "string" }
                                            },
                                            "required": ["ASSISTANT 1", "ASSISTANT 2", "ASSISTANT 3"]
                                        },
                                        "2": {
                                            "type": "object",
                                            "properties": {
                                                "ASSISTANT 1": { "type": "string" },
                                                "ASSISTANT 2": { "type": "string" },
                                                "ASSISTANT 3": { "type": "string" }
                                            },
                                            "required": ["ASSISTANT 1", "ASSISTANT 2", "ASSISTANT 3"]
                                        },
                                        "3": {
                                            "type": "object",
                                            "properties": {
                                                "ASSISTANT 1": { "type": "string" },
                                                "ASSISTANT 2": { "type": "string" },
                                                "ASSISTANT 3": { "type": "string" }
                                            },
                                            "required": ["ASSISTANT 1", "ASSISTANT 2", "ASSISTANT 3"]
                                        },
                                        "4": {
                                            "type": "object",
                                            "properties": {
                                                "ASSISTANT 1": { "type": "string" },
                                                "ASSISTANT 2": { "type": "string" },
                                                "ASSISTANT 3": { "type": "string" }
                                            },
                                            "required": ["ASSISTANT 1", "ASSISTANT 2", "ASSISTANT 3"]
                                        },
                                        "5": {
                                            "type": "object",
                                            "properties": {
                                                "ASSISTANT 1": { "type": "string" },
                                                "ASSISTANT 2": { "type": "string" },
                                                "ASSISTANT 3": { "type": "string" }
                                            },
                                            "required": ["ASSISTANT 1", "ASSISTANT 2", "ASSISTANT 3"]
                                        },
                                        "6": {
                                            "type": "object",
                                            "properties": {
                                                "ASSISTANT 1": { "type": "string" },
                                                "ASSISTANT 2": { "type": "string" },
                                                "ASSISTANT 3": { "type": "string" }
                                            },
                                            "required": ["ASSISTANT 1", "ASSISTANT 2", "ASSISTANT 3"]
                                        }
                                    },
                                    "required": ["1", "2", "3", "4", "5", "6"]
                                }
                            },
                            "required": ["sentence", "questions", "answers"]
                        }
                    }
                },
                "required": ["results"]
            }
        }
    }
)

# %%
print(completion.completion_message.content.text)
# Out:
# {
# "results": [
# {
# "sentence": "1. She ejected him into the street.",
# "answers": {
# "1": {
# "ASSISTANT 1": "The sentence provided implies that 'he' moved.",
# "ASSISTANT 2": "Yes, he moved.",
# "ASSISTANT 3": "The sentence implies that 'he' was relocated."
# },
# "2": {
# "ASSISTANT 1": "The sentence provided does not specify the initial location of 'him', but it implies he was not in the street initially.",
# "ASSISTANT 2": "The initial location of 'him' is not specified, but it was not the street.",
# "ASSISTANT 3": "The sentence implies 'he' was inside or elsewhere before being ejected."
# },
# "3": {
# "ASSISTANT 1": "The sentence provided indicates that 'he' was in the street at the end of the event.",
# "ASSISTANT 2": "He was in the street.",
# "ASSISTANT 3": "At the end of the event, 'he' was in the street."
# },
# "4": {
# "ASSISTANT 1": "The sentence provided implies that 'he' moved because 'she' ejected him.",
# "ASSISTANT 2": "He moved because she ejected him.",
# ...

# %%
# The problem is now the max_completion_tokens
# We cannot have all sentences in the same prompt or we take the risk of output with poor quality

completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": f"You will receive 33 prompt sentences that are:{examples}. The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly. Each question will have three answers, which will start with: The sentence provided.\n 'ASSISTANT(1):' for the first answer.\n 'ASSISTANT(2):' for the second answer.\n 'ASSISTANT(3):' for the first answer. You must answer all 33 sentences. Do not leave a sentence unanswered. Put all the sentences, questions and answers into the specified JSON format",
        },
        {
            "role": "user",
            "content": f"Taking into account these 33 sentences: {examples}, answer the following questions: 1. Did he/she/it move? 2. Where was he/she/it at the beginning of the event described in the sentence above? 3. Where was he/she/it at the end of the event described in the sentence above? 4. Why did he/she/it move? 5. Who or what performed the action? 6. Please describe this event in another way.",
        },
    ],
    #repetition_penalty=2,
    #max_completion_tokens=100,
    temperature=0,
    max_completion_tokens=6000,
    response_format={
        "type": "json_schema",
        "json_schema": {
            "name": "PromptResponse",
            "schema": {
                "type": "object",
                "properties": {
                    "results": {
                        "type": "array",
                        "items": {
                            "type": "object",
                            "properties": {
                                "sentence": { "type": "string" },
                                "answers": {
                                    "type": "object",
                                    "properties": {
                                        "1": {
                                            "type": "object",
                                            "properties": {
                                                "ASSISTANT 1": { "type": "string" },
                                                "ASSISTANT 2": { "type": "string" },
                                                "ASSISTANT 3": { "type": "string" }
                                            },
                                            "required": ["ASSISTANT 1", "ASSISTANT 2", "ASSISTANT 3"]
                                        },
                                        "2": {
                                            "type": "object",
                                            "properties": {
                                                "ASSISTANT 1": { "type": "string" },
                                                "ASSISTANT 2": { "type": "string" },
                                                "ASSISTANT 3": { "type": "string" }
                                            },
                                            "required": ["ASSISTANT 1", "ASSISTANT 2", "ASSISTANT 3"]
                                        },
                                        "3": {
                                            "type": "object",
                                            "properties": {
                                                "ASSISTANT 1": { "type": "string" },
                                                "ASSISTANT 2": { "type": "string" },
                                                "ASSISTANT 3": { "type": "string" }
                                            },
                                            "required": ["ASSISTANT 1", "ASSISTANT 2", "ASSISTANT 3"]
                                        },
                                        "4": {
                                            "type": "object",
                                            "properties": {
                                                "ASSISTANT 1": { "type": "string" },
                                                "ASSISTANT 2": { "type": "string" },
                                                "ASSISTANT 3": { "type": "string" }
                                            },
                                            "required": ["ASSISTANT 1", "ASSISTANT 2", "ASSISTANT 3"]
                                        },
                                        "5": {
                                            "type": "object",
                                            "properties": {
                                                "ASSISTANT 1": { "type": "string" },
                                                "ASSISTANT 2": { "type": "string" },
                                                "ASSISTANT 3": { "type": "string" }
                                            },
                                            "required": ["ASSISTANT 1", "ASSISTANT 2", "ASSISTANT 3"]
                                        },
                                        "6": {
                                            "type": "object",
                                            "properties": {
                                                "ASSISTANT 1": { "type": "string" },
                                                "ASSISTANT 2": { "type": "string" },
                                                "ASSISTANT 3": { "type": "string" }
                                            },
                                            "required": ["ASSISTANT 1", "ASSISTANT 2", "ASSISTANT 3"]
                                        }
                                    },
                                    "required": ["1", "2", "3", "4", "5", "6"]
                                }
                            },
                            "required": ["sentence", "questions", "answers"]
                        }
                    }
                },
                "required": ["results"]
            }
        }
    }
)

# %%
print(completion.completion_message.content.text)
# Out:
# {
# "results": [
# {
# "sentence": "1. She ejected him into the street.",
# "answers": {
# "1": {
# "ASSISTANT 1": "The sentence provided implies that 'he' moved.",
# "ASSISTANT 2": "Yes, he moved.",
# "ASSISTANT 3": "The sentence implies that 'he' was ejected."
# },
# "2": {
# "ASSISTANT 1": "The sentence provided implies that 'he' was inside or with 'her' at the beginning.",
# "ASSISTANT 2": "'He' was presumably inside or near 'her'.",
# "ASSISTANT 3": "The exact initial location is not specified, but it was not in the street."
# },
# "3": {
# "ASSISTANT 1": "The sentence provided indicates that 'he' was in the street at the end.",
# "ASSISTANT 2": "'He' ended up in the street.",
# "ASSISTANT 3": "The final location of 'he' was in the street."
# },
# "4": {
# "ASSISTANT 1": "The sentence provided suggests that 'he' moved because 'she' ejected him.",
# "ASSISTANT 2": "'He' moved because of 'her' action.",
# "ASSISTANT 3": "The reason for the movement was 'her' ejection of 'him'."
# ...

# %%
print(completion.model_dump_json())
# Out:
# {"completion_message":{"role":"assistant","content":{"text":"{\n\"results\": [\n{\n\"sentence\": \"1. She ejected him into the street.\",\n\"answers\": {\n\"1\": {\n\"ASSISTANT 1\": \"The sentence provided implies that 'he' moved.\",\n\"ASSISTANT 2\": \"Yes, he moved.\",\n\"ASSISTANT 3\": \"The sentence implies that 'he' was ejected.\"\n},\n\"2\": {\n\"ASSISTANT 1\": \"The sentence provided implies that 'he' was inside or with 'her' at the beginning.\",\n\"ASSISTANT 2\": \"'He' was presumably inside or near 'her'.\",\n\"ASSISTANT 3\": \"The exact initial location is not specified, but it was not in the street.\"\n},\n\"3\": {\n\"ASSISTANT 1\": \"The sentence provided indicates that 'he' was in the street at the end.\",\n\"ASSISTANT 2\": \"'He' ended up in the street.\",\n\"ASSISTANT 3\": \"The final location of 'he' was in the street.\"\n},\n\"4\": {\n\"ASSISTANT 1\": \"The sentence provided suggests that 'he' moved because 'she' ejected him.\",\n\"ASSISTANT 2\": \"'He' moved because
# ...

# %% [markdown]
# ## Test 10: Best prompt + division of sentences

# %%
completion = client.chat.completions.create(
    model="Llama-4-Maverick-17B-128E-Instruct-FP8",
    messages=[
        {
            "role": "system",
            "content": f"""
            You will receive 8 prompt sentences that are:{sents_1}. 
            The user will then give you a series of questions about its implications or an instruction, which you will respond to accurately and succinctly.
            Each question will have three answers, which will start with:
            The sentence provided.
            'ASSISTANT(1):' for the first answer.
            'ASSISTANT(2):' for the second answer.
            'ASSISTANT(3):' for the first answer.
            
            REMEMBER: You MUST answer all 8 sentences. Do not leave any sentence unanswered. Follow the specified format for all sentences, questions and answers.
            """,
        },
        {
            "role": "user",
            "content": f"""Taking into account these 8 sentences: {sents_1}, answer the following questions: 
            1. Did he/she/it move?
            2. Where was he/she/it at the beginning of the event described in the sentence above?
            3. Where was he/she/it at the end of the event described in the sentence above?
            4. Why did he/she/it move? 5. Who or what performed the action?
            6. Please describe this event in another way. Do not leave any question unanswered.""",
        },
    ],
    #repetition_penalty=2,
    #max_completion_tokens=100,
    temperature=0,
    max_completion_tokens=6000,
)

# %%
print(completion.completion_message.content.text)
# Out:
# I'll be happy to help. Here are the answers to the questions for each of the 8 sentences.
#
# **1. She ejected him into the street.**
# 1. Did he/she/it move?
# The sentence provided.
# ASSISTANT(1): Yes, 'him' moved.
# ASSISTANT(2): The subject 'him' was moved by 'She'.
# ASSISTANT(3): The action caused 'him' to change location.
#
# 2. Where was he/she/it at the beginning of the event described in the sentence above?
# The sentence provided.
# ASSISTANT(1): The sentence doesn't specify the initial location of 'him'.
# ASSISTANT(2): 'He' was presumably inside or with 'her' before being ejected.
# ASSISTANT(3): The exact starting location is not given.
#
# 3. Where was he/she/it at the end of the event described in the sentence above?
# The sentence provided.
# ASSISTANT(1): 'He' was in the street.
# ASSISTANT(2): The final location of 'him' was in the street.
# ASSISTANT(3): 'Him' ended up in the street.
#
# 4. Why did he/she/it move?
# The sentence provided.
# ...
